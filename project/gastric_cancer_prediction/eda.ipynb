# %% [markdown]
# **Loading the Libraries**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('seaborn-v0_8')

# %% [markdown]
# **Loading Dataset**

# %% [markdown]
# And displaying the first five rows

# %%
df = pd.read_csv("Dataset/gastric_cancer_detection_dataset.csv")
df.head()
# Out:
#    age  gender    ethnicity geographical_location  family_history  \
# 0   43    Male  Ethnicity_A                 Other               1
# 1   86  Female  Ethnicity_B            California               1
# 2   68    Male  Ethnicity_A            California               0
# 3   57  Female  Ethnicity_A                 Other               0
# 4   33    Male  Ethnicity_A            California               0
#
#    smoking_habits  alcohol_consumption  helicobacter_pylori_infection  \
# 0               0                    0                              0
# 1               0                    0                              1
# 2               1                    1                              0
# 3               0                    0                              1
# 4               1                    1                              0
#
#   dietary_habits existing_conditions  ...     elmmo microcosm   miranda  \
# 0       Low_Salt   Chronic Gastritis  ...  0.187003  0.786422  0.204816
# 1      High_Salt            Diabetes  ...  0.493322  0.963989  0.498041
# 2      High_Salt                 NaN  ...  0.573560  0.666896  0.540388
# 3      High_Salt   Chronic Gastritis  ...  0.261399  0.949488  0.134170
# 4      High_Salt            Diabetes  ...  0.754478  0.263164  0.876767
#
#       mirdb    pictar      pita  targetscan  predicted.sum   all.sum  label
# 0  0.561920  0.438175  0.283603    0.928244       4.324299  7.666791      0
# 1  0.985585  0.144609  0.375375    0.103573       7.967674  1.483280      0
# 2  0.905853  0.827279  0.350915    0.166878       3.748651  3.046783      0
# 3  0.429935  0.935231  0.794704    0.867036       5.478298  8.811307      0
# 4  0.650832  0.337669  0.427492    0.915804       1.809181  0.394632      0
#
# [5 rows x 29 columns]

# %%
# basic information of the dataset
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 212354 entries, 0 to 212353
# Data columns (total 29 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   age                            212354 non-null  int64
#  1   gender                         212354 non-null  str
#  2   ethnicity                      212354 non-null  str
#  3   geographical_location          212354 non-null  str
#  4   family_history                 212354 non-null  int64
#  5   smoking_habits                 212354 non-null  int64
#  6   alcohol_consumption            212354 non-null  int64
#  7   helicobacter_pylori_infection  212354 non-null  int64
#  8   dietary_habits                 212354 non-null  str
#  9   existing_conditions            169868 non-null  str
#  10  endoscopic_images              212354 non-null  str
#  11  biopsy_results                 212354 non-null  str
#  12  ct_scan                        212354 non-null  str
#  13  mature_mirna_acc               212354 non-null  str
#  14  mature_mirna_id                212354 non-null  str
#  15  target_symbol                  212354 non-null  str
#  16  target_entrez                  212354 non-null  int64
#  17  target_ensembl                 212354 non-null  int64
#  18  diana_microt                   212354 non-null  float64
#  19  elmmo                          212354 non-null  float64
#  20  microcosm                      212354 non-null  float64
#  21  miranda                        212354 non-null  float64
#  22  mirdb                          212354 non-null  float64
#  23  pictar                         212354 non-null  float64
#  24  pita                           212354 non-null  float64
#  25  targetscan                     212354 non-null  float64
#  26  predicted.sum                  212354 non-null  float64
#  27  all.sum                        212354 non-null  float64
#  28  label                          212354 non-null  int64
# dtypes: float64(10), int64(8), str(11)
# memory usage: 47.0 MB

# %%
# describing the dataset to note consistency of value
display(df.describe())
df.describe(include='all')
# Out:
#                  age  family_history  smoking_habits  alcohol_consumption  \
# count  212354.000000   212354.000000   212354.000000        212354.000000
# mean       53.258036        0.300564        0.399154             0.499378
# std        18.984419        0.458504        0.489726             0.500001
# min        20.000000        0.000000        0.000000             0.000000
# 25%        37.000000        0.000000        0.000000             0.000000
# 50%        50.000000        0.000000        0.000000             0.000000
# 75%        69.000000        1.000000        1.000000             1.000000
# max        89.000000        1.000000        1.000000             1.000000
#
#        helicobacter_pylori_infection  target_entrez  target_ensembl  \
# count                  212354.000000  212354.000000    2.123540e+05
# mean                        0.249470    5496.117332    1.499874e+06
# std                         0.432707    2596.817632    2.882585e+05
# min                         0.000000    1000.000000    1.000007e+06
# 25%                         0.000000    3252.000000    1.251177e+06
# 50%                         0.000000    5491.000000    1.500324e+06
# 75%                         0.000000    7738.000000    1.748424e+06
# max                         1.000000    9999.000000    1.999998e+06
#
#         diana_microt         elmmo      microcosm        miranda  \
# count  212354.000000  2.123540e+05  212354.000000  212354.000000
# mean        0.500527  4.994971e-01       0.500083       0.499895
# std         0.288757  2.888452e-01       0.288491       0.288571
# min         0.000005  6.089062e-07       0.000003       0.000001
# 25%         0.250034  2.486468e-01       0.249877       0.250206
# 50%         0.501302  4.998040e-01       0.500498       0.499635
# 75%         0.750783  7.495843e-01       0.748769       0.749075
# max         0.999998  9.999993e-01       0.999997       0.999997
#
#                mirdb        pictar           pita     targetscan  \
# count  212354.000000  2.123540e+05  212354.000000  212354.000000
# mean        0.500125  4.989745e-01       0.501152       0.501117
# std         0.288738  2.884995e-01       0.288874       0.288678
# min         0.000013  7.743957e-07       0.000008       0.000004
# 25%         0.250293  2.497943e-01       0.250322       0.251790
# 50%         0.499888  4.985230e-01       0.502228       0.501814
# 75%         0.749994  7.487212e-01       0.751212       0.751860
# max         1.000000  9.999986e-01       0.999993       0.999997
#
#        predicted.sum        all.sum          label
# count  212354.000000  212354.000000  212354.000000
# mean        5.010346       5.000085       0.098698
# std         2.884461       2.882685       0.298257
# min         0.000016       0.000081       0.000000
# 25%         2.512241       2.505941       0.000000
# 50%         5.018196       5.003598       0.000000
# 75%         7.508878       7.493106       0.000000
# max         9.999908       9.999987       1.000000
#                   age  gender    ethnicity geographical_location  \
# count   212354.000000  212354       212354                212354
# unique            NaN       2            3                     2
# top               NaN    Male  Ethnicity_A            California
# freq              NaN  148706       127571                169603
# mean        53.258036     NaN          NaN                   NaN
# std         18.984419     NaN          NaN                   NaN
# min         20.000000     NaN          NaN                   NaN
# 25%         37.000000     NaN          NaN                   NaN
# 50%         50.000000     NaN          NaN                   NaN
# 75%         69.000000     NaN          NaN                   NaN
# max         89.000000     NaN          NaN                   NaN
#
#         family_history  smoking_habits  alcohol_consumption  \
# count    212354.000000   212354.000000        212354.000000
# unique             NaN             NaN                  NaN
# top                NaN             NaN                  NaN
# freq               NaN             NaN                  NaN
# mean          0.300564        0.399154             0.499378
# std           0.458504        0.489726             0.500001
# min           0.000000        0.000000             0.000000
# 25%           0.000000        0.000000             0.000000
# 50%           0.000000        0.000000             0.000000
# 75%           1.000000        1.000000             1.000000
# max           1.000000        1.000000             1.000000
#
#         helicobacter_pylori_infection dietary_habits existing_conditions  ...  \
# count                   212354.000000         212354              169868  ...
# unique                            NaN              2                   2  ...
# top                               NaN      High_Salt   Chronic Gastritis  ...
# freq                              NaN         169805              106309  ...
# mean                         0.249470            NaN                 NaN  ...
# std                          0.432707            NaN                 NaN  ...
# min                          0.000000            NaN                 NaN  ...
# 25%                          0.000000            NaN                 NaN  ...
# 50%                          0.000000            NaN                 NaN  ...
# 75%                          0.000000            NaN                 NaN  ...
# max                          1.000000            NaN                 NaN  ...
#
#                elmmo      microcosm        miranda          mirdb  \
# count   2.123540e+05  212354.000000  212354.000000  212354.000000
# unique           NaN            NaN            NaN            NaN
# top              NaN            NaN            NaN            NaN
# freq             NaN            NaN            NaN            NaN
# mean    4.994971e-01       0.500083       0.499895       0.500125
# std     2.888452e-01       0.288491       0.288571       0.288738
# min     6.089062e-07       0.000003       0.000001       0.000013
# 25%     2.486468e-01       0.249877       0.250206       0.250293
# 50%     4.998040e-01       0.500498       0.499635       0.499888
# 75%     7.495843e-01       0.748769       0.749075       0.749994
# max     9.999993e-01       0.999997       0.999997       1.000000
#
#               pictar           pita     targetscan  predicted.sum  \
# count   2.123540e+05  212354.000000  212354.000000  212354.000000
# unique           NaN            NaN            NaN            NaN
# top              NaN            NaN            NaN            NaN
# freq             NaN            NaN            NaN            NaN
# mean    4.989745e-01       0.501152       0.501117       5.010346
# std     2.884995e-01       0.288874       0.288678       2.884461
# min     7.743957e-07       0.000008       0.000004       0.000016
# 25%     2.497943e-01       0.250322       0.251790       2.512241
# 50%     4.985230e-01       0.502228       0.501814       5.018196
# 75%     7.487212e-01       0.751212       0.751860       7.508878
# max     9.999986e-01       0.999993       0.999997       9.999908
#
#               all.sum          label
# count   212354.000000  212354.000000
# unique            NaN            NaN
# top               NaN            NaN
# freq              NaN            NaN
# mean         5.000085       0.098698
# std          2.882685       0.298257
# min          0.000081       0.000000
# 25%          2.505941       0.000000
# 50%          5.003598       0.000000
# 75%          7.493106       0.000000
# max          9.999987       1.000000
#
# [11 rows x 29 columns]

# %%
# viewing the columns of dataset
df.columns
# Out:
# Index(['age', 'gender', 'ethnicity', 'geographical_location', 'family_history',
#        'smoking_habits', 'alcohol_consumption',
#        'helicobacter_pylori_infection', 'dietary_habits',
#        'existing_conditions', 'endoscopic_images', 'biopsy_results', 'ct_scan',
#        'mature_mirna_acc', 'mature_mirna_id', 'target_symbol', 'target_entrez',
#        'target_ensembl', 'diana_microt', 'elmmo', 'microcosm', 'miranda',
#        'mirdb', 'pictar', 'pita', 'targetscan', 'predicted.sum', 'all.sum',
#        'label'],
#       dtype='str')

# %% [markdown]
# All capitalized letter of the columns should be noted

# %%
df.shape
# Out:
# (212354, 29)

# %%
#finding missing values
display(df.isna().sum())
# Out:
# age                                  0
# gender                               0
# ethnicity                            0
# geographical_location                0
# family_history                       0
# smoking_habits                       0
# alcohol_consumption                  0
# helicobacter_pylori_infection        0
# dietary_habits                       0
# existing_conditions              42486
# endoscopic_images                    0
# biopsy_results                       0
# ct_scan                              0
# mature_mirna_acc                     0
# mature_mirna_id                      0
# target_symbol                        0
# target_entrez                        0
# target_ensembl                       0
# diana_microt                         0
# elmmo                                0
# microcosm                            0
# miranda                              0
# mirdb                                0
# pictar                               0
# pita                                 0
# targetscan                           0
# predicted.sum                        0
# all.sum                              0
# label                                0
# dtype: int64

# %% [markdown]
# Missing values in the dataset are shown above

# %%
display(df.shape)
# Out:
# (212354, 29)

# %%
# checking the dataset once again for encoding
df.head()
# Out:
#    age  gender    ethnicity geographical_location  family_history  \
# 0   43    Male  Ethnicity_A                 Other               1
# 1   86  Female  Ethnicity_B            California               1
# 2   68    Male  Ethnicity_A            California               0
# 3   57  Female  Ethnicity_A                 Other               0
# 4   33    Male  Ethnicity_A            California               0
#
#    smoking_habits  alcohol_consumption  helicobacter_pylori_infection  \
# 0               0                    0                              0
# 1               0                    0                              1
# 2               1                    1                              0
# 3               0                    0                              1
# 4               1                    1                              0
#
#   dietary_habits existing_conditions  ...     elmmo microcosm   miranda  \
# 0       Low_Salt   Chronic Gastritis  ...  0.187003  0.786422  0.204816
# 1      High_Salt            Diabetes  ...  0.493322  0.963989  0.498041
# 2      High_Salt                 NaN  ...  0.573560  0.666896  0.540388
# 3      High_Salt   Chronic Gastritis  ...  0.261399  0.949488  0.134170
# 4      High_Salt            Diabetes  ...  0.754478  0.263164  0.876767
#
#       mirdb    pictar      pita  targetscan  predicted.sum   all.sum  label
# 0  0.561920  0.438175  0.283603    0.928244       4.324299  7.666791      0
# 1  0.985585  0.144609  0.375375    0.103573       7.967674  1.483280      0
# 2  0.905853  0.827279  0.350915    0.166878       3.748651  3.046783      0
# 3  0.429935  0.935231  0.794704    0.867036       5.478298  8.811307      0
# 4  0.650832  0.337669  0.427492    0.915804       1.809181  0.394632      0
#
# [5 rows x 29 columns]

# %%
# renaming the columns in small letter for easiness
df.columns = df.columns.str.strip().str.lower()

# %%
#analyzing unique variables
for col in df.columns:
    if df[col].nunique() < 20:
        print(f"{col}: {df[col].unique()}")
# Out:
# gender: <StringArray>
# ['Male', 'Female']
# Length: 2, dtype: str
# ethnicity: <StringArray>
# ['Ethnicity_A', 'Ethnicity_B', 'Ethnicity_C']
# Length: 3, dtype: str
# geographical_location: <StringArray>
# ['Other', 'California']
# Length: 2, dtype: str
# family_history: [1 0]
# smoking_habits: [0 1]
# alcohol_consumption: [0 1]
# helicobacter_pylori_infection: [0 1]
# dietary_habits: <StringArray>
# ['Low_Salt', 'High_Salt']
# Length: 2, dtype: str
# existing_conditions: <StringArray>
# ['Chronic Gastritis', 'Diabetes', nan]
# Length: 3, dtype: str
# endoscopic_images: <StringArray>
# ['Normal', 'Abnormal']
# Length: 2, dtype: str
# biopsy_results: <StringArray>
# ['Negative', 'Positive']
# Length: 2, dtype: str
# ct_scan: <StringArray>
# ['Negative', 'Positive']
# Length: 2, dtype: str
# mature_mirna_acc: <StringArray>
# ['MIR123', 'MIR345', 'MIR234']
# Length: 3, dtype: str
# mature_mirna_id: <StringArray>
# ['MIR123_1', 'MIR234_2', 'MIR345_3']
# Length: 3, dtype: str
# target_symbol: <StringArray>
# ['TP53', 'KRAS', 'CDH1']
# Length: 3, dtype: str
# label: [0 1]

# %% [markdown]
# **Data Preprocessing and Column Dropping**

# %%
# drop ethnicity and geographical_location as we don't need them
df = df.drop(columns=['ethnicity', 'geographical_location'], errors='ignore')
df.head()
# Out:
#    age  gender  family_history  smoking_habits  alcohol_consumption  \
# 0   43    Male               1               0                    0
# 1   86  Female               1               0                    0
# 2   68    Male               0               1                    1
# 3   57  Female               0               0                    0
# 4   33    Male               0               1                    1
#
#    helicobacter_pylori_infection dietary_habits existing_conditions  \
# 0                              0       Low_Salt   Chronic Gastritis
# 1                              1      High_Salt            Diabetes
# 2                              0      High_Salt                 NaN
# 3                              1      High_Salt   Chronic Gastritis
# 4                              0      High_Salt            Diabetes
#
#   endoscopic_images biopsy_results  ...     elmmo microcosm   miranda  \
# 0            Normal       Negative  ...  0.187003  0.786422  0.204816
# 1            Normal       Negative  ...  0.493322  0.963989  0.498041
# 2            Normal       Negative  ...  0.573560  0.666896  0.540388
# 3            Normal       Negative  ...  0.261399  0.949488  0.134170
# 4          Abnormal       Negative  ...  0.754478  0.263164  0.876767
#
#       mirdb    pictar      pita  targetscan  predicted.sum   all.sum  label
# 0  0.561920  0.438175  0.283603    0.928244       4.324299  7.666791      0
# 1  0.985585  0.144609  0.375375    0.103573       7.967674  1.483280      0
# 2  0.905853  0.827279  0.350915    0.166878       3.748651  3.046783      0
# 3  0.429935  0.935231  0.794704    0.867036       5.478298  8.811307      0
# 4  0.650832  0.337669  0.427492    0.915804       1.809181  0.394632      0
#
# [5 rows x 27 columns]

# %% [markdown]
# **Binary Encoding**

# %%
binary_mappings = {
    'gender': {'Male': 1, 'Female': 0},
    'dietary_habits': {'High_Salt': 1, 'Low_Salt': 0},
    'endoscopic_images': {'Abnormal': 1, 'Normal': 0},
    'biopsy_results': {'Positive': 1, 'Negative': 0},
    'ct_scan': {'Positive': 1, 'Negative': 0}
}

for col, mapping in binary_mappings.items():
    if col in df.columns:
        df[col] = df[col].map(mapping)

df.head()
# Out:
#    age  gender  family_history  smoking_habits  alcohol_consumption  \
# 0   43       1               1               0                    0
# 1   86       0               1               0                    0
# 2   68       1               0               1                    1
# 3   57       0               0               0                    0
# 4   33       1               0               1                    1
#
#    helicobacter_pylori_infection  dietary_habits existing_conditions  \
# 0                              0               0   Chronic Gastritis
# 1                              1               1            Diabetes
# 2                              0               1                 NaN
# 3                              1               1   Chronic Gastritis
# 4                              0               1            Diabetes
#
#    endoscopic_images  biopsy_results  ...     elmmo microcosm   miranda  \
# 0                  0               0  ...  0.187003  0.786422  0.204816
# 1                  0               0  ...  0.493322  0.963989  0.498041
# 2                  0               0  ...  0.573560  0.666896  0.540388
# 3                  0               0  ...  0.261399  0.949488  0.134170
# 4                  1               0  ...  0.754478  0.263164  0.876767
#
#       mirdb    pictar      pita  targetscan  predicted.sum   all.sum  label
# 0  0.561920  0.438175  0.283603    0.928244       4.324299  7.666791      0
# 1  0.985585  0.144609  0.375375    0.103573       7.967674  1.483280      0
# 2  0.905853  0.827279  0.350915    0.166878       3.748651  3.046783      0
# 3  0.429935  0.935231  0.794704    0.867036       5.478298  8.811307      0
# 4  0.650832  0.337669  0.427492    0.915804       1.809181  0.394632      0
#
# [5 rows x 27 columns]

# %% [markdown]
# Duplicate Values

# %%
duplicates = df.duplicated().sum()
print(duplicates)
# Out:
# 0

# %% [markdown]
# Data dones't contain any duplicated values, which is perfect for us!

# %%
df[df.duplicated()].head()
# Out:
# Empty DataFrame
# Columns: [age, gender, family_history, smoking_habits, alcohol_consumption, helicobacter_pylori_infection, dietary_habits, existing_conditions, endoscopic_images, biopsy_results, ct_scan, mature_mirna_acc, mature_mirna_id, target_symbol, target_entrez, target_ensembl, diana_microt, elmmo, microcosm, miranda, mirdb, pictar, pita, targetscan, predicted.sum, all.sum, label]
# Index: []
#
# [0 rows x 27 columns]

# %% [markdown]
# A comparison of target variable distribution before and after duplicate removal

# %% [markdown]
# ### Handling Missing Values ###

# %%
df[df["existing_conditions"].isna()][
    [
        "existing_conditions",
        "endoscopic_images",
        "biopsy_results",
        "helicobacter_pylori_infection"
    ]
]
# Out:
#        existing_conditions  endoscopic_images  biopsy_results  \
# 2                      NaN                  0               0
# 8                      NaN                  0               0
# 12                     NaN                  0               1
# 14                     NaN                  0               0
# 16                     NaN                  0               1
# ...                    ...                ...             ...
# 212318                 NaN                  1               0
# 212333                 NaN                  0               0
# 212334                 NaN                  0               1
# 212351                 NaN                  1               0
# 212353                 NaN                  0               1
#
#         helicobacter_pylori_infection
# 2                                   0
# 8                                   1
# 12                                  0
# 14                                  0
# 16                                  0
# ...                               ...
# 212318                              0
# 212333                              1
# 212334                              0
# 212351                              0
# 212353                              1
#
# [42486 rows x 4 columns]

# %% [markdown]
# Above df shows that for some patients have cases of abnormal endoscopic images, positive biopsy results, and helocobater pylori infection despite none existing conditions.
# Let's first obeserve the count of it

# %%
count_endoscopic = df[
    (df["existing_conditions"].isna()) &
    (df["endoscopic_images"] == 1)
].shape[0]

print(f"Number of patients for Abnormal Endoscopi images: {count_endoscopic}")

count_biopsy = df[
    (df["existing_conditions"].isna()) &
    (df["biopsy_results"] == 1)
].shape[0]

print(f"Number of patients with positive biopsy result: {count_biopsy}")

count_infection = df[
    (df["existing_conditions"].isna()) &
    (df["helicobacter_pylori_infection"] == 1)
].shape[0]

print(f"Number of patients with helicobacter pylori infection: {count_infection}")
# Out:
# Number of patients for Abnormal Endoscopi images: 12779
# Number of patients with positive biopsy result: 4308
# Number of patients with helicobacter pylori infection: 10653

# %%
missing_mask = df["existing_conditions"].isna()

print(pd.crosstab(missing_mask, df["label"], normalize="index") * 100)
# Out:
# label                        0          1
# existing_conditions
# False                90.168837   9.831163
# True                 89.975521  10.024479

# %% [markdown]
# Filling missing values with "unknown"

# %%
df["existing_conditions"] = df["existing_conditions"].fillna("Unknown")

# %%
df.isna().sum()
# Out:
# age                              0
# gender                           0
# family_history                   0
# smoking_habits                   0
# alcohol_consumption              0
# helicobacter_pylori_infection    0
# dietary_habits                   0
# existing_conditions              0
# endoscopic_images                0
# biopsy_results                   0
# ct_scan                          0
# mature_mirna_acc                 0
# mature_mirna_id                  0
# target_symbol                    0
# target_entrez                    0
# target_ensembl                   0
# diana_microt                     0
# elmmo                            0
# microcosm                        0
# miranda                          0
# mirdb                            0
# pictar                           0
# pita                             0
# targetscan                       0
# predicted.sum                    0
# all.sum                          0
# label                            0
# dtype: int64

# %% [markdown]
# One-hot encoding the existing category column

# %%
df = pd.get_dummies(
    df,
    columns=["existing_conditions"],
    drop_first=False
)

# %%
df.head()
# Out:
#    age  gender  family_history  smoking_habits  alcohol_consumption  \
# 0   43       1               1               0                    0
# 1   86       0               1               0                    0
# 2   68       1               0               1                    1
# 3   57       0               0               0                    0
# 4   33       1               0               1                    1
#
#    helicobacter_pylori_infection  dietary_habits  endoscopic_images  \
# 0                              0               0                  0
# 1                              1               1                  0
# 2                              0               1                  0
# 3                              1               1                  0
# 4                              0               1                  1
#
#    biopsy_results  ct_scan  ...     mirdb    pictar      pita  targetscan  \
# 0               0        0  ...  0.561920  0.438175  0.283603    0.928244
# 1               0        0  ...  0.985585  0.144609  0.375375    0.103573
# 2               0        0  ...  0.905853  0.827279  0.350915    0.166878
# 3               0        0  ...  0.429935  0.935231  0.794704    0.867036
# 4               0        0  ...  0.650832  0.337669  0.427492    0.915804
#
#    predicted.sum   all.sum  label  existing_conditions_Chronic Gastritis  \
# 0       4.324299  7.666791      0                                   True
# 1       7.967674  1.483280      0                                  False
# 2       3.748651  3.046783      0                                  False
# 3       5.478298  8.811307      0                                   True
# 4       1.809181  0.394632      0                                  False
#
#    existing_conditions_Diabetes  existing_conditions_Unknown
# 0                         False                        False
# 1                          True                        False
# 2                         False                         True
# 3                         False                        False
# 4                          True                        False
#
# [5 rows x 29 columns]

# %% [markdown]
# ### Checking the Datatype once again ###

# %%
df.dtypes
# Out:
# age                                        int64
# gender                                     int64
# family_history                             int64
# smoking_habits                             int64
# alcohol_consumption                        int64
# helicobacter_pylori_infection              int64
# dietary_habits                             int64
# endoscopic_images                          int64
# biopsy_results                             int64
# ct_scan                                    int64
# mature_mirna_acc                             str
# mature_mirna_id                              str
# target_symbol                                str
# target_entrez                              int64
# target_ensembl                             int64
# diana_microt                             float64
# elmmo                                    float64
# microcosm                                float64
# miranda                                  float64
# mirdb                                    float64
# pictar                                   float64
# pita                                     float64
# targetscan                               float64
# predicted.sum                            float64
# all.sum                                  float64
# label                                      int64
# existing_conditions_Chronic Gastritis       bool
# existing_conditions_Diabetes                bool
# existing_conditions_Unknown                 bool
# dtype: object

# %% [markdown]
# ### still three columns remain as string on which we can't operate ###
#
# mature_mirna_acc is an identifier which we don't need
# mature_mirna_id & target_symbol can be meaningful health records which we have to inspect first

# %%
print(df["mature_mirna_id"].nunique())
print(df.shape[0])

print(df["target_symbol"].nunique())
print(df.shape[0])
# Out:
# 3
# 212354
# 3
# 212354

# %% [markdown]
# this means these are low-cardinality categorical variable that can affect the prediction, so we will one-hot encode them

# %%
df.drop(columns=["mature_mirna_acc"], inplace=True)

# %%
df = pd.get_dummies(
    df,
    columns=["mature_mirna_id", "target_symbol"],
    drop_first=False
)

# %%
df.head()
# Out:
#    age  gender  family_history  smoking_habits  alcohol_consumption  \
# 0   43       1               1               0                    0
# 1   86       0               1               0                    0
# 2   68       1               0               1                    1
# 3   57       0               0               0                    0
# 4   33       1               0               1                    1
#
#    helicobacter_pylori_infection  dietary_habits  endoscopic_images  \
# 0                              0               0                  0
# 1                              1               1                  0
# 2                              0               1                  0
# 3                              1               1                  0
# 4                              0               1                  1
#
#    biopsy_results  ct_scan  ...  label  existing_conditions_Chronic Gastritis  \
# 0               0        0  ...      0                                   True
# 1               0        0  ...      0                                  False
# 2               0        0  ...      0                                  False
# 3               0        0  ...      0                                   True
# 4               0        0  ...      0                                  False
#
#    existing_conditions_Diabetes  existing_conditions_Unknown  \
# 0                         False                        False
# 1                          True                        False
# 2                         False                         True
# 3                         False                        False
# 4                          True                        False
#
#    mature_mirna_id_MIR123_1  mature_mirna_id_MIR234_2  \
# 0                      True                     False
# 1                     False                      True
# 2                     False                     False
# 3                      True                     False
# 4                      True                     False
#
#    mature_mirna_id_MIR345_3  target_symbol_CDH1  target_symbol_KRAS  \
# 0                     False               False               False
# 1                     False               False               False
# 2                      True               False                True
# 3                     False               False                True
# 4                     False                True               False
#
#    target_symbol_TP53
# 0                True
# 1                True
# 2               False
# 3               False
# 4               False
#
# [5 rows x 32 columns]

# %% [markdown]
# Exporting the cleaned dataset

# %%
df.to_csv("Dataset/cleaned_gcs_bibs.csv", index=False)
